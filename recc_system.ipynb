# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("Indeed_WebScraping\indeed_jobs_modified.csv")

# Text preprocessing
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(df['Job Description'])

# Function to recommend jobs based on input text
def recommend_jobs(input_text, df, tfidf_matrix, tfidf_vectorizer, top_n=3):
    input_vector = tfidf_vectorizer.transform([input_text])
    cosine_similarities = cosine_similarity(input_vector, tfidf_matrix).flatten()
    related_jobs_indices = cosine_similarities.argsort()[:-top_n-1:-1]
    recommended_jobs = df.iloc[related_jobs_indices]
    return recommended_jobs

# %%
# Example usage
input_text = "data science, machine learning, data analysis, ai"
recommend_jobs(input_text, df, tfidf_matrix, tfidf_vectorizer)
# Out:
#                                Job Title                        Company  \
# 262  Software and Applications Manager\n  JOYFULAI TECHNOLOGY PTE. LTD.
# 124              Summer Internship 2024                       Munich Re
# 23               Summer Internship 2024                       Munich Re
#
#                          Salary               Job Type   Location  \
# 262  $10,000 - $13,000 a month    Permanent, Full-time  Singapore
# 124                         NaN             Internship  Singapore
# 23                          NaN             Internship  Singapore
#
#                                        Job Description  Posted Date  \
# 262  Joyful AI, an innovative AI technology startup...  PostedToday
# 124  Summer Internship 2024 - Data Analyst & BI Int...  PostedToday
# 23   Summer Internship 2024 - Data Analyst & BI Int...  PostedToday
#
#      Today Date         Listing Date
# 262  2024-03-21  2024-03-21 00:00:00
# 124  2024-03-21  2024-03-21 00:00:00
# 23   2024-03-21  2024-03-21 00:00:00

# %%
input_text = "data science"
recommend_jobs(input_text, df, tfidf_matrix, tfidf_vectorizer)
# Out:
#                                     Job Title                    Company  \
# 119                 DATA ANALYTICS (Health)\n    RESOURCE HUNT PTE. LTD.
# 192                       Solution Architect                 SoftwareOne
# 286  Software Development Senior Specialist\n  NTT Data Services Pte Ltd
#
#                         Salary              Job Type          Location  \
# 119  $9,000 - $10,000 a month              Full-time         Singapore
# 192                        NaN             Full-time  Singapore 189720
# 286                        NaN  Permanent, Full-time         Singapore
#
#                                        Job Description  \
# 119  Health Analytics Manager\nJoin our team and he...
# 192  Job Function: Software & Cloud Services The ro...
# 286  S\nPosted by\nShubhansh Jaiswal\nTalent Acquis...
#
#                  Posted Date  Today Date         Listing Date
# 119        PostedJust posted  2024-03-21  2024-03-21 00:00:00
# 192  PostedPosted 2 days ago  2024-03-21  2024-03-19 00:00:00
# 286              PostedToday  2024-03-21  2024-03-21 00:00:00

# %%
input_text = "data analysis"
recommend_jobs(input_text, df, tfidf_matrix, tfidf_vectorizer)
# Out:
#                                              Job Title                Company  \
# 167                                     Data Analyst\n  COGNOSPHERE PTE. LTD.
# 170                                     Data Analyst\n              NodeFlair
# 140  Customer Excellence Data Analytics & Reporting...                Cargill
#
#                         Salary               Job Type   Location  \
# 167  $7,000 - $14,000 a month    Permanent, Full-time  Singapore
# 170   $7,000 - $14,000 a month                    NaN  Singapore
# 140                        NaN                    NaN  Singapore
#
#                                        Job Description  \
# 167  Who Are We?\nAt HoYoverse, we are committed to...
# 170  Job Summary\n\nSalary\nS$7,000 - S$14,000 / Mo...
# 140  Job Purpose and Impact\n\nThe role of Commerci...
#
#                  Posted Date  Today Date         Listing Date
# 167  PostedPosted 2 days ago  2024-03-21  2024-03-19 00:00:00
# 170  PostedPosted 2 days ago  2024-03-21  2024-03-19 00:00:00
# 140   PostedPosted 1 day ago  2024-03-21  2024-03-20 00:00:00

# %%
input_text = "machine learning"
recommend_jobs(input_text, df, tfidf_matrix, tfidf_vectorizer)
# Out:
#                                      Job Title                    Company  \
# 208             Workforce Operations Analyst\n                      Apple
# 204  Quantitative Trader/Analyst Commodities\n        KS Talent Solutions
# 222                        Software Engineer\n  ETUAN MECHATRONIC PTE LTD
#
#                        Salary              Job Type   Location  \
# 208                       NaN                   NaN  Singapore
# 204                       NaN  Permanent, Full-time  Singapore
# 222  $3,500 - $4,500 a month              Full-time  Singapore
#
#                                        Job Description  \
# 208  Summary\n\nPosted: 15 Mar 2024\n\nRole Number:...
# 204  Join our client in an exciting role based in S...
# 222  Design and develops software for PLC/PC/Vision...
#
#                  Posted Date  Today Date         Listing Date
# 208  PostedPosted 2 days ago  2024-03-21  2024-03-19 00:00:00
# 204  PostedPosted 2 days ago  2024-03-21  2024-03-19 00:00:00
# 222        PostedJust posted  2024-03-21  2024-03-21 00:00:00

# %% [markdown]
# # Rec system
# - cold start problem - use content based approach
#   - standard nlp process,
#   - user profiles info to start rec
#   - e.g. k-NN model
# - avoid rule based / search engine like recc system
# - lack of labels, unsupervised method
#   - PCA
# - copy paste resume in to get rec jobs: https://towardsdatascience.com/building-a-job-recommender-for-non-technical-business-roles-via-nlp-and-machine-learning-626c4039931e
# - azure cloud deployment, 10months old
#   - https://github.com/abbas99-hub/Job-Recommendation-System
#   - https://medium.com/@abbasbehrain95/creating-an-ai-powered-job-recommendation-system-50ce1cd12d36
# - microsoft resource: https://azure.microsoft.com/en-us/blog/building-recommender-systems-with-azure-machine-learning-service/
